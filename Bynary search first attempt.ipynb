# %%
from collections import Counter
Counter(bin(8))['1']

# %%
arr = [1024,512,256,128,64,32,16,8,4,2,1]
from collections import defaultdict
occurences = defaultdict(list)
from collections import Counter
for elem in arr:
    count = Counter(bin(elem))['1']
    occurences[count].append(elem)

    

solution = []
for count in sorted(occurences.keys()):
    solution.extend(sorted(occurences[count]))
print(solution)
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]

# %%
nums1 = [1,2,3,0,0,0]
m = 3
nums2 = [2,5,6]
n = 3

nums1 = nums1[:m]
second = nums2[:n]
nums1.extend(second)
nums1.sort()
nums1
# Out:
# [1, 2, 2, 3, 5, 6]

# %%
# Out:
# [0, 0, 1, 3, 4, '_', '_', '_']
# 5

# %%
## the judge does not care about creating the new list , everything should be done in place , 
nums  = [3,2,2,3]
val = 3



from collections import Counter
c =Counter(nums)
elements_to_add = c[val]
c.pop(val)

nums = [elment for elment in c.elements()]
e = len(nums)
nums.extend(["_"] * elements_to_add)


print(nums)
print(e)
# Out:
# [2, 2, '_', '_']
# 2

# %%
nums  = [0,1,2,2,3,0,4,2]

val = 2
k=0

counter =0
for i in range(len(nums)):
    if nums[i] != val:
        nums[k] = nums[i]
        k+=1
print(k)
# Out:
# 5

# %%
class Node:
    def __init__(self, value, next=None):
        self.value = value
        self.next = next
    
    def __repr__(self):
        return f"Node({self.value})"
    
    def __eq__(self, other):
        if isinstance(other, Node):
            return self.value == other.value
        return self.value == other

h = [1, 2, 3, 4, 5]
k = 2
final_list = []
# Crear lista enlazada
head= None
for element in h:
    new_node = Node(element, None)
    if head is not None:
        head.next = new_node
    final_list.append(new_node)
    head= new_node


amount_of_rotations = k % len(final_list)
final_list = final_list[-amount_of_rotations:] + final_list[:-amount_of_rotations]
final_list
# Out:
# [Node(4), Node(5), Node(1), Node(2), Node(3)]

# %%
class Solution:
    def rotateRight(self, head: Optional[ListNode], k: int) -> Optional[ListNode]:
        
        if not head or not head.next or k == 0:
            return head
        
        length = 1
        tail = head
        
        while tail.next:
            tail = tail.next
            length += 1
        
        k = k % length
        if k == 0:
            return head
        
        tail.next = head
        
        steps_to_new_tail = length - k - 1
        new_tail = head
        
        for _ in range(steps_to_new_tail):
            new_tail = new_tail.next
        
        new_head = new_tail.next
        new_tail.next = None
        
        return new_head
# Out:
# [Node(4), Node(5), Node(1), Node(2), Node(3)]

# %%
# find quadruplets 

nums = [1,0,-1,0,-2,2]
target = 0
result = set()
sum = 0
for i in range(len(nums)):
    for j in range(i+1, len(nums)):
        for k in range(j+1, len(nums)):
            for l in range(k+1, len(nums)):
                sum = nums[i] + nums[j] + nums[k] + nums[l]
                if sum == target:
                    result.add((nums[i], nums[j], nums[k], nums[l]))
                    print(nums[i], nums[j], nums[k], nums[l], target)
[list(e) for e in result]
# Out:
# 1 0 -1 0 0
# 1 -1 -2 2 0
# 0 0 -2 2 0
# [[0, 0, -2, 2], [1, 0, -1, 0], [1, -1, -2, 2]]

# %%
class Solution:
    def fourSum(self, nums: List[int], target: int) -> List[List[int]]:
        nums.sort()
        result = []
        n = len(nums)
        
        for i in range(n - 3):
            if i > 0 and nums[i] == nums[i - 1]:
                continue
                
            for j in range(i + 1, n - 2):
                if j > i + 1 and nums[j] == nums[j - 1]:
                    continue
                
                left = j + 1
                right = n - 1
                
                while left < right:
                    total = nums[i] + nums[j] + nums[left] + nums[right]
                    
                    if total == target:
                        result.append([nums[i], nums[j], nums[left], nums[right]])
                        
                        left += 1
                        right -= 1
                        
                        while left < right and nums[left] == nums[left - 1]:
                            left += 1
                            
                        while left < right and nums[right] == nums[right + 1]:
                            right -= 1
                    
                    elif total < target:
                        left += 1
                    else:
                        right -= 1
                        
        return result
# Out:
# [1, 0, -1, 0, -2, 2]

# %%
# Given an array of positive integers,
# return the number of elements that are strictly
# greater than the average of all previous elements.
# Skip the first element.

r = [100, 200, 150,300]
c = 0
for index, elem in enumerate(r[1:]):
    average = sum(r[:index+1]) / (index+1)
    if elem > average:
        c+=1
print(c)
# Out:
# 2

# %%
#Given an array of intervals [startTime, endTime], merge all overlapping intervals and return a sorted array of non-overlapping intervals.
intervals = [[1, 3], [2, 6], [8, 10], [15, 18]]
intervals.sort(key=lambda x: x[0])
intervals
# Out:
# [[1, 3], [2, 6], [8, 10], [15, 18]]

# %%
intervals = [[1, 3], [2, 6], [8, 10], [15, 18]]
intervals.sort(key=lambda x: x[0])
element= 0
while element < len(intervals)-1:
    b = intervals[element][0]
    e = intervals[element][1]
    if e >= intervals[element+1][0]:
        intervals[element][1] = max(intervals[element][1], intervals[element+1][1])
        intervals.pop(element+1)
    element+=1
print(intervals)
# Out:
# [[1, 6], [8, 10], [15, 18]]

# %%
#Given an integer array nums and integers k and M, count the number of contiguous subarrays whose sum equals k and whose maximum element is at most M.
nums = [1,5]
total = 5
m = 5
counter =0
for index, e in enumerate(nums):
    element = index
    addition = []
    print(element)
    while nums[element] <= m and element < len(nums):
        addition.append(nums[element])
        print("Current sum: ", addition, nums[element])
        if sum(addition) == total:
            print("possible solution: ", addition)
            counter +=1
            break
        element+=1
print(counter)
# Out:
# 0
# Current sum:  [1] 1
# Current sum:  [1, 5] 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 10
#       8 addition = []
#       9 print(element)
# ---> 10 while nums[element] <= m and element < len(nums):
#      11     addition.append(nums[element])
#      12     print("Current sum: ", addition, nums[element])
#
# IndexError: list index out of range

# %%
#Given an integer array nums and integers k and M, count the number of contiguous subarrays whose sum equals k and whose maximum element is at most M.
# CORREGIDO: element < len(nums) ANTES de nums[element]
nums = [1,5]
total = 5
m = 5
counter =0
for index, e in enumerate(nums):
    element = index
    addition = []
    print(element)
    while element < len(nums) and nums[element] <= m:  # ORDEN CORRECTO
        addition.append(nums[element])
        print("Current sum: ", addition, nums[element])
        if sum(addition) == total:
            print("possible solution: ", addition)
            counter +=1
            break
        element+=1
print("Total:", counter)
# Out:
# 0
# Current sum:  [1] 1
# Current sum:  [1, 5] 5
# 1
# Current sum:  [5] 5
# possible solution:  [5]
# Total: 1

# %%
##version corregida : 
def countSubarraysWithSumAndMaxAtMost(nums, k, M):
    from collections import defaultdict
    
    count = 0
    prefix_count = defaultdict(int)
    prefix_count[0] = 1
    current_sum = 0
    
    for num in nums:
        if num > M:
            
            prefix_count = defaultdict(int)
            prefix_count[0] = 1
            current_sum = 0
        else:
            current_sum += num
            count += prefix_count[current_sum - k]
            prefix_count[current_sum] += 1
    
    return count
