# %%
sample = ["987654321111111", "811111111111119", "234234234234278", "818181911112111"]
import requests
url = "https://adventofcode.com/2025/day/3/input"
session = "53616c7465645f5f4fc9ce9761c1c5fefa47aab8a7c9c4dd1be33644e6afa1c733f4ce8b2890fb1b385cb39624b88c1dc19d9d0cc8e7d640b18dfed7da1be127"
cookies = {"session": session}
response = requests.get(url, cookies=cookies)
parsed_real_data = (response.text).splitlines()

# %%
voltagee = []
for line in parsed_real_data:
    max=""
    for index in range(len(line)):
        first = line[index]
        for second_index in range(index + 1, len(line)):
            second = line[second_index]
            candidate = first + second
            if candidate > max:
                print("New max found:", candidate)
                max = candidate
    voltagee.append(max)
print(voltagee)
sum([int(c) for c in voltagee])

# %%
line = "234234234234278"
max = "00"
for index in range(len(line)):
    first = line[index]
    for second_index in range(index + 1, len(line)):
        second = line[second_index]
        candidate = first + second
        if candidate > max:
            max = candidate
            
print(max)

# %%
len(sample[0]) == len(parsed_real_data[0])
# Out:
# False

# %%
len(parsed_real_data[0])
# Out:
# 100
